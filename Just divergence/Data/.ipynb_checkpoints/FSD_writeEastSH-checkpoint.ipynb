# %%
import glob
import xarray as xr
import netCDF4
import h5netcdf
import scipy
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
file_paths = glob.glob('/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-[0][5-9]-*') 
file_paths
# Out:
# ['/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-06-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-05-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-09-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-08-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-01-07-03600.nc']

# %%
ds = xr.open_mfdataset(file_paths, combine='by_coords')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 120, nbnd: 2, nj: 480, ni: 540, nc: 5, nkice: 8,
#                        nksnow: 3, nkbio: 5, nkaer: 7, nf: 12, nvertices: 4)
# Coordinates:
#   * time              (time) object 0023-01-04 23:29:59.986267 ... 0023-01-09...
#     TLON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     TLAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NCAT              (nc) float32 dask.array<chunksize=(5,), meta=np.ndarray>
#     NFSD              (nf) float32 dask.array<chunksize=(12,), meta=np.ndarray>
# Dimensions without coordinates: nbnd, nj, ni, nc, nkice, nksnow, nkbio, nkaer,
#                                 nf, nvertices
# Data variables: (12/68)
#     time_bounds       (time, nbnd) object dask.array<chunksize=(1, 2), meta=np.ndarray>
#     VGRDi             (time, nkice) float32 dask.array<chunksize=(1, 8), meta=np.ndarray>
#     VGRDs             (time, nksnow) float32 dask.array<chunksize=(1, 3), meta=np.ndarray>
#     VGRDb             (time, nkbio) float32 dask.array<chunksize=(1, 5), meta=np.ndarray>
#     VGRDa             (time, nkaer) float32 dask.array<chunksize=(1, 7), meta=np.ndarray>
#     tmask             (time, nj, ni) float32 dask.array<chunksize=(1, 480, 540), meta=np.ndarray>
#     ...                ...
#     before_afsd_seco  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     before_afsd_midd  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_last_  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_secon  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_middl  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     afsdn_h           (time, nc, nf, nj, ni) float32 dask.array<chunksize=(1, 5, 12, 480, 540), meta=np.ndarray>
# Attributes:
#     title:               NilsFSAdapt
#     contents:            Diagnostic and Prognostic Variables
#     source:              CICE Sea Ice Model, unknown_version_name
#     comment:             All years have exactly 365 days
#     comment2:            File written on model date 00230105
#     comment3:            seconds elapsed into model date:      0
#     time_period_freq:    hour_1
#     time_axis_position:  middle
#     conventions:         CF-1.0
#     history:             This dataset was created on 2024-10-25 at 00:41
#     io_flavor:           io_pio2 cdf1

# %%
#.isel(ni=slice(140,300) .isel(ni=slice(336,336+50)
plt.contourf(ds.aice_h[0].isel(nj=slice(83,100)).isel(ni=slice(523,9999)),levels=100)

# %%
#Now for southern hemisphere...
latSH=slice(83,100)
longSH=slice(523,9999)
dshigh=ds.isel(nj=latSH).isel(ni=longSH)
ds_inSH = []
ds_outSH = []

# Loop over each time, nj, and ni
for t in range(len(ds.time)): # Ignore first time step ds.dims['time']
    for j in range(dshigh.dims['nj']):
        for i in range(dshigh.dims['ni']):
            divu = dshigh.divu_h[t, j, i].values / 100
            if divu>0.055: divu=0.0549
            # Check if none of the values are NaNs
            
            if dshigh.aice_h[t,j,i].values>0.1:
                if divu>0.01:
                    # Extract the 12 (nf) values for each variable
                    before_afsd_last = dshigh.before_afsd_last[t, :, j, i].values
                    after_afsd_last_ = dshigh.after_afsd_last_[t, :, j, i].values
                    before_afsd_seco = dshigh.before_afsd_seco[t, :, j, i].values
                    after_afsd_secon = dshigh.after_afsd_secon[t, :, j, i].values
                    before_afsd_midd = dshigh.before_afsd_midd[t, :, j, i].values
                    after_afsd_middl = dshigh.after_afsd_middl[t, :, j, i].values

                    
                    if not (np.isnan(before_afsd_last).any() or np.isnan(after_afsd_last_).any()) and not((before_afsd_last==0).any()): # and before_afsd_midd[-1]>0.1
                        hold1=after_afsd_last_ - before_afsd_last
                        ds_inSH.append((before_afsd_last, divu))
                        ds_outSH.append((hold1))
                    
                    
                    if not (np.isnan(before_afsd_seco).any() or np.isnan(after_afsd_secon).any()) and not((before_afsd_seco==0).any()):
                        hold2=after_afsd_secon - before_afsd_seco
                        ds_inSH.append((before_afsd_seco, divu))
                        ds_outSH.append((hold2))
                    
                    if not (np.isnan(before_afsd_midd).any() or np.isnan(after_afsd_middl).any()) and not((before_afsd_midd==0).any()):
                        hold3=after_afsd_middl - before_afsd_midd
                        ds_inSH.append((before_afsd_midd, divu))
                        ds_outSH.append((hold3))
            
ds_inSH = np.array([np.append(arr, scalar) for arr, scalar in ds_inSH])

# %%
len(ds_outSH)
# Out:
# 0

# %%
# Create CSV files for ds_in and ds_out
np.savetxt('ds_inEastSH30day10.csv', ds_inSH, delimiter=',')
np.savetxt('ds_outEastSH30day10.csv', ds_outSH, delimiter=',')
