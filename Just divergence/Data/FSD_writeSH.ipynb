# %%
import glob
import xarray as xr
import netCDF4
import h5netcdf
import scipy
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
file_paths = glob.glob('/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-[1][0-9]-*') 
file_paths
# Out:
# ['/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-17-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-11-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-10-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-15-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-16-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-18-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-12-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-14-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-13-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-19-39600.nc']

# %%
ds = xr.open_mfdataset(file_paths, combine='by_coords')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 240, nbnd: 2, nj: 480, ni: 540, nc: 5, nkice: 8,
#                        nksnow: 3, nkbio: 5, nkaer: 7, nf: 12, nvertices: 4)
# Coordinates:
#   * time              (time) object 0023-02-09 23:29:59.780273 ... 0023-02-19...
#     TLON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     TLAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NCAT              (nc) float32 dask.array<chunksize=(5,), meta=np.ndarray>
#     NFSD              (nf) float32 dask.array<chunksize=(12,), meta=np.ndarray>
# Dimensions without coordinates: nbnd, nj, ni, nc, nkice, nksnow, nkbio, nkaer,
#                                 nf, nvertices
# Data variables: (12/68)
#     time_bounds       (time, nbnd) object dask.array<chunksize=(1, 2), meta=np.ndarray>
#     VGRDi             (time, nkice) float32 dask.array<chunksize=(1, 8), meta=np.ndarray>
#     VGRDs             (time, nksnow) float32 dask.array<chunksize=(1, 3), meta=np.ndarray>
#     VGRDb             (time, nkbio) float32 dask.array<chunksize=(1, 5), meta=np.ndarray>
#     VGRDa             (time, nkaer) float32 dask.array<chunksize=(1, 7), meta=np.ndarray>
#     tmask             (time, nj, ni) float32 dask.array<chunksize=(1, 480, 540), meta=np.ndarray>
#     ...                ...
#     before_afsd_seco  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     before_afsd_midd  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_last_  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_secon  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_middl  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     afsdn_h           (time, nc, nf, nj, ni) float32 dask.array<chunksize=(1, 5, 12, 480, 540), meta=np.ndarray>
# Attributes:
#     title:               NilsFSAdapt
#     contents:            Diagnostic and Prognostic Variables
#     source:              CICE Sea Ice Model, unknown_version_name
#     comment:             All years have exactly 365 days
#     comment2:            File written on model date 00230210
#     comment3:            seconds elapsed into model date:      0
#     time_period_freq:    hour_1
#     time_axis_position:  middle
#     conventions:         CF-1.0
#     history:             This dataset was created on 2024-10-28 at 18:28
#     io_flavor:           io_pio2 cdf1

# %%
plt.contourf(ds.aice_h[50].isel(nj=slice(55,93)).isel(ni=slice(140,300)),levels=100)

# %%
#Now for southern hemisphere...
latSH=slice(55,93)
longSH=slice(140,300)
dshigh=ds.isel(nj=latSH).isel(ni=longSH)
ds_inSH = []
ds_outSH = []

# Loop over each time, nj, and ni
for t in range(len(ds.time)): # Ignore first time step ds.dims['time']
    for j in range(dshigh.dims['nj']):
        for i in range(dshigh.dims['ni']):
            divu = dshigh.divu_h[t, j, i].values / 100
            if divu>0.055: divu=0.0549
            # Check if none of the values are NaNs
            
            if dshigh.aice_h[t,j,i].values>0.1:
                if divu>0.01:
                    # Extract the 12 (nf) values for each variable
                    before_afsd_last = dshigh.before_afsd_last[t, :, j, i].values
                    after_afsd_last_ = dshigh.after_afsd_last_[t, :, j, i].values
                    before_afsd_seco = dshigh.before_afsd_seco[t, :, j, i].values
                    after_afsd_secon = dshigh.after_afsd_secon[t, :, j, i].values
                    before_afsd_midd = dshigh.before_afsd_midd[t, :, j, i].values
                    after_afsd_middl = dshigh.after_afsd_middl[t, :, j, i].values

                    
                    if not (np.isnan(before_afsd_last).any() or np.isnan(after_afsd_last_).any()) and not((before_afsd_last==0).any()): # and before_afsd_midd[-1]>0.1
                        hold1=after_afsd_last_ - before_afsd_last
                        ds_inSH.append((before_afsd_last, divu))
                        ds_outSH.append((hold1))
                    
                    
                    if not (np.isnan(before_afsd_seco).any() or np.isnan(after_afsd_secon).any()) and not((before_afsd_seco==0).any()):
                        hold2=after_afsd_secon - before_afsd_seco
                        ds_inSH.append((before_afsd_seco, divu))
                        ds_outSH.append((hold2))
                    
                    if not (np.isnan(before_afsd_midd).any() or np.isnan(after_afsd_middl).any()) and not((before_afsd_midd==0).any()):
                        hold3=after_afsd_middl - before_afsd_midd
                        ds_inSH.append((before_afsd_midd, divu))
                        ds_outSH.append((hold3))
            
ds_inSH = np.array([np.append(arr, scalar) for arr, scalar in ds_inSH])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 for j in range(dshigh.dims['nj']):
#      11     for i in range(dshigh.dims['ni']):
# ---> 12         divu = dshigh.divu_h[t, j, i].values / 100
#      13         if divu>0.055: divu=0.0549
#      14         # Check if none of the values are NaNs
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/xarray/core/dataarray.py:733, in DataArray.values(self)
#     724 @property
#     725 def values(self) -> np.ndarray:
#     726     """
#     727     The array's data as a numpy.ndarray.
#     728
#    (...)
#     731     type does not support coercion like this (e.g. cupy).
#     732     """
# --> 733     return self.variable.values
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/xarray/core/variable.py:614, in Variable.values(self)
#     611 @property
#     612 def values(self):
#     613     """The variable's data as a numpy.ndarray"""
# --> 614     return _as_array_or_item(self._data)
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/xarray/core/variable.py:314, in _as_array_or_item(data)
#     300 def _as_array_or_item(data):
#     301     """Return the given values as a numpy array, or as an individual item if
#     302     it's a 0d datetime64 or timedelta64 array.
#     303
#    (...)
#     312     TODO: remove this (replace with np.asarray) once these issues are fixed
#     313     """
# --> 314     data = np.asarray(data)
#     315     if data.ndim == 0:
#     316         if data.dtype.kind == "M":
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/array/core.py:1694, in Array.__array__(self, dtype, **kwargs)
#    1693 def __array__(self, dtype=None, **kwargs):
# -> 1694     x = self.compute()
#    1695     if dtype and x.dtype != dtype:
#    1696         x = x.astype(dtype)
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/base.py:376, in DaskMethodsMixin.compute(self, **kwargs)
#     352 def compute(self, **kwargs):
#     353     """Compute this dask collection
#     354
#     355     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     374     dask.compute
#     375     """
# --> 376     (result,) = compute(self, traverse=False, **kwargs)
#     377     return result
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/base.py:657, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     649     return args
#     651 schedule = get_scheduler(
#     652     scheduler=scheduler,
#     653     collections=collections,
#     654     get=get,
#     655 )
# --> 657 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#     658 keys, postcomputes = [], []
#     659 for x in collections:
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/base.py:426, in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     424 for opt, val in groups.items():
#     425     dsk, keys = _extract_graph_and_keys(val)
# --> 426     dsk = opt(dsk, keys, **kwargs)
#     428     for opt_inner in optimizations:
#     429         dsk = opt_inner(dsk, keys, **kwargs)
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/array/optimization.py:49, in optimize(dsk, keys, fuse_keys, fast_functions, inline_functions_fast_functions, rename_fused_keys, **kwargs)
#      46 if not isinstance(dsk, HighLevelGraph):
#      47     dsk = HighLevelGraph.from_collections(id(dsk), dsk, dependencies=())
# ---> 49 dsk = optimize_blockwise(dsk, keys=keys)
#      50 dsk = fuse_roots(dsk, keys=keys)
#      51 dsk = dsk.cull(set(keys))
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/blockwise.py:1079, in optimize_blockwise(graph, keys)
#    1054 def optimize_blockwise(graph, keys=()):
#    1055     """High level optimization of stacked Blockwise layers
#    1056
#    1057     For operations that have multiple Blockwise operations one after the other, like
#    (...)
#    1077     rewrite_blockwise
#    1078     """
# -> 1079     out = _optimize_blockwise(graph, keys=keys)
#    1080     while out.dependencies != graph.dependencies:
#    1081         graph = out
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/blockwise.py:1141, in _optimize_blockwise(full_graph, keys)
#    1138 blockwise_layers.add(dep)
#    1140 # traverse further to this child's children
# -> 1141 output_indices = set(layers[dep].output_indices)
#    1142 input_indices = {
#    1143     i for _, ind in layers[dep].indices if ind for i in ind
#    1144 }
#    1145 is_io_superset = output_indices.issuperset(input_indices)
#
# KeyboardInterrupt:

# %%
len(ds_outSH)
# Out:
# 0

# %%
# Create CSV files for ds_in and ds_out
np.savetxt('ds_inSH30day50.csv', ds_inSH, delimiter=',')
np.savetxt('ds_outSH30day50.csv', ds_outSH, delimiter=',')
