# %%
import glob
import xarray as xr
import netCDF4
import h5netcdf
import scipy
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
file_paths = glob.glob('/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-0[0-9]*') 
file_paths
# Out:
# ['/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-46800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-14400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-61200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-50400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-02-79200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-10800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-00000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-32400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-07200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-07-36000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-54000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-03-18000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-57600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-03600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-25200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-68400.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-09-72000.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-75600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-06-43200.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-39600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-01-64800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-05-21600.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-08-28800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-82800.nc',
#  '/glade/derecho/scratch/geraint/archive/NilsFSAdapt/ice/hist/NilsFSAdapt.cice.h2_01h.0023-02-04-25200.nc']

# %%
ds = xr.open_mfdataset(file_paths, combine='by_coords')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 216, nbnd: 2, nj: 480, ni: 540, nc: 5, nkice: 8,
#                        nksnow: 3, nkbio: 5, nkaer: 7, nf: 12, nvertices: 4)
# Coordinates:
#   * time              (time) object 0023-01-31 23:30:00.109863 ... 0023-02-09...
#     TLON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     TLAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELON              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELAT              (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NCAT              (nc) float32 dask.array<chunksize=(5,), meta=np.ndarray>
#     NFSD              (nf) float32 dask.array<chunksize=(12,), meta=np.ndarray>
# Dimensions without coordinates: nbnd, nj, ni, nc, nkice, nksnow, nkbio, nkaer,
#                                 nf, nvertices
# Data variables: (12/68)
#     time_bounds       (time, nbnd) object dask.array<chunksize=(1, 2), meta=np.ndarray>
#     VGRDi             (time, nkice) float32 dask.array<chunksize=(1, 8), meta=np.ndarray>
#     VGRDs             (time, nksnow) float32 dask.array<chunksize=(1, 3), meta=np.ndarray>
#     VGRDb             (time, nkbio) float32 dask.array<chunksize=(1, 5), meta=np.ndarray>
#     VGRDa             (time, nkaer) float32 dask.array<chunksize=(1, 7), meta=np.ndarray>
#     tmask             (time, nj, ni) float32 dask.array<chunksize=(1, 480, 540), meta=np.ndarray>
#     ...                ...
#     before_afsd_seco  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     before_afsd_midd  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_last_  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_secon  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     after_afsd_middl  (time, nf, nj, ni) float32 dask.array<chunksize=(1, 12, 480, 540), meta=np.ndarray>
#     afsdn_h           (time, nc, nf, nj, ni) float32 dask.array<chunksize=(1, 5, 12, 480, 540), meta=np.ndarray>
# Attributes:
#     title:               NilsFSAdapt
#     contents:            Diagnostic and Prognostic Variables
#     source:              CICE Sea Ice Model, unknown_version_name
#     comment:             All years have exactly 365 days
#     comment2:            File written on model date 00230201
#     comment3:            seconds elapsed into model date:      0
#     time_period_freq:    hour_1
#     time_axis_position:  middle
#     conventions:         CF-1.0
#     history:             This dataset was created on 2024-10-28 at 17:52
#     io_flavor:           io_pio2 cdf1

# %%
plt.contourf(ds.aice_h[0].isel(nj=slice(403,9999)).isel(ni=slice(120,190)),levels=100)

# %%
# Initialize empty lists to store the data
latBering = slice(403, 9999)
longBering = slice(120, 190)
dshigh = ds.isel(nj=latBering).isel(ni=longBering)
print(dshigh.dims['nj'])
ds_inBering = []
ds_outBering = []

# Loop over each time, nj, and ni
for t in range(len(ds.time)):  # Ignore first time step ds.dims['time']
    for j in range(dshigh.dims['nj']):
        for i in range(dshigh.dims['ni']):
            divu = dshigh.divu_h[t, j, i].values / 100
            if divu > 0.055:
                divu = 0.0549
            # Check if none of the values are NaNs

            if dshigh.aice_h[t, j, i].values > 0.1:
                if divu > 0.01:
                    # Extract the 12 (nf) values for each variable
                    before_afsd_last = dshigh.before_afsd_last[t, :, j, i].values
                    after_afsd_last_ = dshigh.after_afsd_last_[t, :, j, i].values
                    before_afsd_seco = dshigh.before_afsd_seco[t, :, j, i].values
                    after_afsd_secon = dshigh.after_afsd_secon[t, :, j, i].values
                    before_afsd_midd = dshigh.before_afsd_midd[t, :, j, i].values
                    after_afsd_middl = dshigh.after_afsd_middl[t, :, j, i].values

                    if not (np.isnan(before_afsd_last).any() or np.isnan(after_afsd_last_).any()) and not ((before_afsd_last == 0).any()):  # and before_afsd_midd[-1]>0.1
                        hold1 = after_afsd_last_ - before_afsd_last
                        ds_inBering.append((before_afsd_last, divu))
                        ds_outBering.append((hold1))

                    if not (np.isnan(before_afsd_seco).any() or np.isnan(after_afsd_secon).any()) and not ((before_afsd_seco == 0).any()):
                        hold2 = after_afsd_secon - before_afsd_seco
                        ds_inBering.append((before_afsd_seco, divu))
                        ds_outBering.append((hold2))

                    if not (np.isnan(before_afsd_midd).any() or np.isnan(after_afsd_middl).any()) and not ((before_afsd_midd == 0).any()):
                        hold3 = after_afsd_middl - before_afsd_midd
                        ds_inBering.append((before_afsd_midd, divu))
                        ds_outBering.append((hold3))

ds_inBering = np.array([np.append(arr, scalar) for arr, scalar in ds_inBering])
# Out:
# 77
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 21
#      18 if dshigh.aice_h[t, j, i].values > 0.1:
#      19     if divu > 0.01:
#      20         # Extract the 12 (nf) values for each variable
# ---> 21         before_afsd_last = dshigh.before_afsd_last[t, :, j, i].values
#      22         after_afsd_last_ = dshigh.after_afsd_last_[t, :, j, i].values
#      23         before_afsd_seco = dshigh.before_afsd_seco[t, :, j, i].values
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/xarray/core/dataarray.py:733, in DataArray.values(self)
#     724 @property
#     725 def values(self) -> np.ndarray:
#     726     """
#     727     The array's data as a numpy.ndarray.
#     728
#    (...)
#     731     type does not support coercion like this (e.g. cupy).
#     732     """
# --> 733     return self.variable.values
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/xarray/core/variable.py:614, in Variable.values(self)
#     611 @property
#     612 def values(self):
#     613     """The variable's data as a numpy.ndarray"""
# --> 614     return _as_array_or_item(self._data)
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/xarray/core/variable.py:314, in _as_array_or_item(data)
#     300 def _as_array_or_item(data):
#     301     """Return the given values as a numpy array, or as an individual item if
#     302     it's a 0d datetime64 or timedelta64 array.
#     303
#    (...)
#     312     TODO: remove this (replace with np.asarray) once these issues are fixed
#     313     """
# --> 314     data = np.asarray(data)
#     315     if data.ndim == 0:
#     316         if data.dtype.kind == "M":
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/array/core.py:1694, in Array.__array__(self, dtype, **kwargs)
#    1693 def __array__(self, dtype=None, **kwargs):
# -> 1694     x = self.compute()
#    1695     if dtype and x.dtype != dtype:
#    1696         x = x.astype(dtype)
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/base.py:376, in DaskMethodsMixin.compute(self, **kwargs)
#     352 def compute(self, **kwargs):
#     353     """Compute this dask collection
#     354
#     355     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     374     dask.compute
#     375     """
# --> 376     (result,) = compute(self, traverse=False, **kwargs)
#     377     return result
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/base.py:664, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     661     postcomputes.append(x.__dask_postcompute__())
#     663 with shorten_traceback():
# --> 664     results = schedule(dsk, keys, **kwargs)
#     666 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/my_env/lib/python3.12/site-packages/dask/local.py:323, in identity(x)
#     319         raise exc.with_traceback(tb)
#     320     raise exc
# --> 323 def identity(x):
#     324     """Identity function. Returns x.
#     325
#     326     >>> identity(3)
#     327     3
#     328     """
#     329     return x
#
# KeyboardInterrupt:

# %%
len(ds_inBering)
# Out:
# 17587

# %%
# Create CSV files for ds_in and ds_out
np.savetxt('ds_inBering30day41.csv', ds_inBering, delimiter=',')
np.savetxt('ds_outBering30day41.csv', ds_outBering, delimiter=',')
len(ds_inBering)
# Out:
# 17587
