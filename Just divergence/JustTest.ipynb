# %%
import glob
import xarray as xr
import netCDF4
import h5netcdf
import scipy
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
file=glob.glob('/glade/derecho/scratch/geraint/NilsFSAdapt/run/NilsFSAdapt.cice.h1.0001-01-03.nc')
file
# Out:
# []

# %%
ds = xr.open_mfdataset(file, combine='by_coords')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ds = xr.open_mfdataset(file, combine='by_coords')
#
# File ~/.local/lib/python3.10/site-packages/xarray/backends/api.py:990, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     987 paths = _find_absolute_paths(paths, engine=engine, **kwargs)
#     989 if not paths:
# --> 990     raise OSError("no files to open")
#     992 if combine == "nested":
#     993     if isinstance(concat_dim, (str, DataArray)) or concat_dim is None:
#
# OSError: no files to open

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 1, nbnd: 2, nj: 480, ni: 540, nc: 5, nkice: 8,
#                    nksnow: 3, nkbio: 5, nkaer: 7, nf: 12, nvertices: 4)
# Coordinates:
#   * time          (time) object 0001-01-04 09:30:00.013733
#     TLON          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     TLAT          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULON          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ULAT          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLON          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     NLAT          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELON          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
#     ELAT          (nj, ni) float32 dask.array<chunksize=(480, 540), meta=np.ndarray>
# ...
